# %% [markdown]
# <a href="https://colab.research.google.com/github/Kripasree-coder/MachineLearning/blob/main/Ad_Sale_Prediction_from_an_existing_customer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Advertisement Sales Prediction From Existing Customer - Logistic Regression

# %%
#Importing libraries
import numpy as np
import pandas as pd

# %%
#Choose dataset file from Local Directory
dataset=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DigitalAd_dataset.csv')

# %%
dataset.head()
# Out:
#    Age  Salary  Status
# 0   18   82000       0
# 1   29   80000       0
# 2   47   25000       1
# 3   45   26000       1
# 4   46   28000       1

# %%
dataset.shape
# Out:
# (400, 3)

# %%
dataset.describe()
# Out:
#               Age         Salary      Status
# count  400.000000     400.000000  400.000000
# mean    37.655000   69742.500000    0.357500
# std     10.482877   34096.960282    0.479864
# min     18.000000   15000.000000    0.000000
# 25%     29.750000   43000.000000    0.000000
# 50%     37.000000   70000.000000    0.000000
# 75%     46.000000   88000.000000    1.000000
# max     60.000000  150000.000000    1.000000

# %%
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,-1].values

# %%
#Splitting dataset into Train & Test
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
print(X_train)
# Out:
# [[ 0.97446763  0.56400811]
#  [-1.52088611 -1.28151705]
#  [ 0.30264162  0.03671521]
#  [-0.36918439 -0.81281224]
#  [ 0.49459191  1.20847722]
#  [-0.1772341   0.82765456]
#  [-0.27320924 -0.78351819]
#  [ 0.39861676  0.24177356]
#  [-0.27320924  0.00742116]
#  [ 0.01471619 -0.60775389]
#  [ 0.11069133  0.00742116]
#  [-0.46515953  2.29235707]
#  [ 0.39861676 -0.02187289]
#  [-0.27320924 -1.28151705]
#  [ 1.93421906 -1.39869325]
#  [-0.27320924  2.23376897]
#  [ 0.11069133  1.03271291]
#  [-0.56113467  1.44282962]
#  [ 0.97446763  1.85294632]
#  [ 0.30264162  0.03671521]
#  [-1.13698554 -1.04716465]
#  [-0.08125895  0.27106761]
#  [ 0.30264162 -0.54916579]
#  [-0.27320924 -0.60775389]
#  [ 0.87849248 -1.39869325]
#  [ 0.78251734 -0.34410744]
#  [-0.46515953 -1.252223  ]
#  [ 0.20666648  0.12459736]
#  [ 0.39861676  0.97412481]
#  [-0.56113467  1.35494747]
#  [-0.46515953 -0.05116694]
#  [-0.56113467  2.32165112]
#  [-0.75308496  0.27106761]
#  [ 1.16641791 -0.78351819]
# ...

# %%
#Training
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# PREDICTION FOR ALL TEST DATA

# %%
#Predicting
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(Y_test,y_pred)
print("Confusion Matrix:\n",cm)
# Out:
# Confusion Matrix:
#  [[61  0]
#  [20 19]]

# %%
#Accuracy
print("Accuracy :",accuracy_score(Y_test,y_pred)*100)
# Out:
# Accuracy : 80.0

# %% [markdown]
# PREDICTION OF NEW CUSTOMER

# %%
age=int(input("Enter New Customer Age:"))
sal=int(input("Enter New Customer Salary:"))
newCust=[[age,sal]]
result=model.predict(sc.transform(newCust))
if result==1:
  print("Customer will Buy")
else:
  print("Customer won't Buy")
# Out:
# Enter New Customer Age:18
# Enter New Customer Salary:15000
# Customer will Buy
